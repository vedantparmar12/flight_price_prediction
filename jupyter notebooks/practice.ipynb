# %%
# !pip install missingno
# Out:
# ...
#   Obtaining dependency information for missingno from https://files.pythonhosted.org/packages/87/22/cd5cf999af21c2f97486622c551ac3d07361ced8125121e907f588ff5f24/missingno-0.5.2-py3-none-any.whl.metadata
# ...

# %%
import pandas as pd

import missingno as msno

import eda_helper_functions as eda

# %%
df = pd.read_csv(r"C:\Users\vedan\Desktop\flight_price_pred\data\titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # missingno - Tutorial

# %% [markdown]
# ## 1. Matrix

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# ## 2. Bar

# %%
msno.bar(df)
# Out:
# <Axes: >

# %% [markdown]
# ## 3. Heatmap

# %%
msno.heatmap(df)
# Out:
# <Axes: >

# %% [markdown]
# ## 4. Dendrogram

# %%
msno.dendrogram(df)
# Out:
# <Axes: >

# %% [markdown]
# ## EDA Helper Functions

# %%
cars = pd.read_csv(r"C:\Users\vedan\Desktop\flight_price_pred\data\car-details.csv")
cars.sample(5)
# Out:
#                              name  year  selling_price  km_driven    fuel  \
# 3403  Maruti Wagon R VXI Optional  2015         260000      40000  Petrol
# 753      Maruti Wagon R LXI BS IV  2013         330000      55425  Petrol
# 1697  Maruti Ertiga SHVS ZDI Plus  2016         760000      49000  Diesel
# 557           Maruti SX4 Vxi BSIV  2012         225000     110000  Petrol
# 3726          Maruti Alto 800 LXI  2014         180000      61000  Petrol
#
#      seller_type transmission         owner
# 3403  Individual       Manual   First Owner
# 753       Dealer       Manual   First Owner
# 1697  Individual       Manual   First Owner
# 557   Individual       Manual  Second Owner
# 3726  Individual       Manual   First Owner

# %%
eda.cat_bivar_plots(cars, "seller_type", "owner")
# Out:
# <h2>Bi-variate Analysis between seller_type and owner</h2>
# <h3></h3>

# %%
train = pd.read_csv(r"C:\Users\vedan\Desktop\flight_price_pred\data\train.csv")
train
# Out:
#           airline date_of_journey    source destination  dep_time  \
# 0     Jet Airways      2019-03-21  Banglore   New Delhi  08:55:00
# 1     Jet Airways      2019-03-27     Delhi      Cochin  17:30:00
# 2           Goair      2019-03-09  Banglore   New Delhi  11:40:00
# 3       Air India      2019-06-12   Kolkata    Banglore  09:25:00
# 4     Jet Airways      2019-03-12  Banglore   New Delhi  22:55:00
# ...           ...             ...       ...         ...       ...
# 6690  Jet Airways      2019-03-21     Delhi      Cochin  10:45:00
# 6691    Air India      2019-05-01   Kolkata    Banglore  09:25:00
# 6692  Jet Airways      2019-06-01     Delhi      Cochin  14:00:00
# 6693     Air Asia      2019-06-24     Delhi      Cochin  07:55:00
# 6694    Air India      2019-03-01  Banglore   New Delhi  11:50:00
#
#      arrival_time  duration  total_stops              additional_info  price
# 0        19:10:00       615          1.0  In-flight meal not included   7832
# ...

# %%
train.airline.value_counts()
# Out:
# airline
# Jet Airways          2391
# Indigo               1296
# Air India            1076
# Multiple Carriers     736
# Spicejet              537
# Vistara               322
# Air Asia              211
# Goair                 125
# Trujet                  1
# Name: count, dtype: int64

# %%
train.airline.value_counts(normalize=True)
# Out:
# airline
# Jet Airways          0.357132
# Indigo               0.193577
# Air India            0.160717
# Multiple Carriers    0.109933
# Spicejet             0.080209
# Vistara              0.048096
# Air Asia             0.031516
# Goair                0.018671
# Trujet               0.000149
# Name: proportion, dtype: float64
